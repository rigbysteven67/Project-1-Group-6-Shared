# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Path of csv file, originally converted using tabula
covid_excess_deaths_path = "Resources/Excess_Deaths_Associated_with_COVID-19.csv"

# Read the csv file
covid_excess_deaths_df = pd.read_csv(covid_excess_deaths_path, low_memory=False)

# %%
# Display the data table for preview
print()
print(f"Excess Deaths Probably Associated with Covid-19 Dataset")
covid_excess_deaths_df.head()
# Out:
# Excess Deaths Probably Associated with Covid-19 Dataset
#   Week Ending Date    State  Observed Number  Upper Bound Threshold  \
# 0       2017-01-14  Alabama           1130.0                 1188.0
# 1       2017-01-21  Alabama           1048.0                 1201.0
# 2       2017-01-28  Alabama           1026.0                 1216.0
# 3       2017-02-04  Alabama           1036.0                 1216.0
# 4       2017-02-11  Alabama           1058.0                 1207.0
#
#    Exceeds Threshold  Average Expected Count  Excess Lower Estimate  \
# 0              False                  1029.0                    0.0
# 1              False                  1042.0                    0.0
# 2              False                  1057.0                    0.0
# 3              False                  1057.0                    0.0
# 4              False                  1053.0                    0.0
#
#    Excess Higher Estimate  Year  Total Excess Lower Estimate in 2020  \
# 0                   101.0  2017                                 3743
# 1                     6.0  2017                                 3743
# 2                     0.0  2017                                 3743
# 3                     0.0  2017                                 3743
# 4                     5.0  2017                                 3743
#
#    Total Excess Higher Estimate in 2020  Percent Excess Lower Estimate  \
# 0                                  5884                            0.0
# 1                                  5884                            0.0
# 2                                  5884                            0.0
# 3                                  5884                            0.0
# 4                                  5884                            0.0
#
#    Percent Excess Higher Estimate                  Type     Outcome Suppress  \
# 0                             0.1  Predicted (weighted)  All causes      NaN
# 1                             0.0  Predicted (weighted)  All causes      NaN
# 2                             0.0  Predicted (weighted)  All causes      NaN
# 3                             0.0  Predicted (weighted)  All causes      NaN
# 4                             0.0  Predicted (weighted)  All causes      NaN
#
#   Note
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# For convenience
df = covid_excess_deaths_df

# %%
# Create list of US states (unique)
states_list = df.State.unique().tolist()

# Remove non-state list entitites
states_list.remove('United States')
states_list.remove('Puerto Rico')
states_list.remove('New York City')
states_list.remove('District of Columbia')

print(states_list)
print()

# Count and print number of US states (unique) as a check
num_states = len(states_list)
print(f"Number of States and Territories = {num_states}")
# Out:
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
#
# Number of States and Territories = 50

# %%
# Create list of dates (unique weeks)
date_list = df["Week Ending Date"].unique().tolist()

# Count number of dates (unique weeks)
num_weeks = len(date_list)
num_years = (num_weeks / 52)
print(f"Reported Period = {round(num_years, 1)} Years")

# Report earliest and latest dates
earliest_date = df["Week Ending Date"].min()
latest_date = df["Week Ending Date"].max()
print(f"Earliest date is {earliest_date}")
print(f"Latest date is {latest_date}")
# Out:
# Reported Period = 3.8 Years
# Earliest date is 2017-01-14
# Latest date is 2020-10-17

# %%
# Sort by State and then Week Ending Date
df = df.sort_values(["State", "Week Ending Date"], ascending = (False, True))

# %%
# DEMONSTRATION OF EXTRACTION AND PROCESSING METHODOLOGY FOR A SINGLE STATE, ALABAMA

al_df = df.loc[df["State"] == "Alabama"]
al_df.head()
# Out:
#       Week Ending Date    State  Observed Number  Upper Bound Threshold  \
# 0           2017-01-14  Alabama           1130.0                 1188.0
# 10638       2017-01-14  Alabama           1130.0                 1188.0
# 21276       2017-01-14  Alabama           1130.0                 1188.0
# 1           2017-01-21  Alabama           1048.0                 1201.0
# 10639       2017-01-21  Alabama           1048.0                 1201.0
#
#        Exceeds Threshold  Average Expected Count  Excess Lower Estimate  \
# 0                  False                  1029.0                    0.0
# 10638              False                  1029.0                    0.0
# 21276              False                  1029.0                    0.0
# 1                  False                  1042.0                    0.0
# 10639              False                  1042.0                    0.0
#
#        Excess Higher Estimate  Year  Total Excess Lower Estimate in 2020  \
# 0                       101.0  2017                                 3743
# 10638                   101.0  2017                                  499
# 21276                   101.0  2017                                 3187
# 1                         6.0  2017                                 3743
# 10639                     6.0  2017                                  499
#
#        Total Excess Higher Estimate in 2020  Percent Excess Lower Estimate  \
# 0                                      5884                            0.0
# 10638                                  2080                            0.0
# 21276                                  5131                            0.0
# 1                                      5884                            0.0
# 10639                                  2080                            0.0
#
#        Percent Excess Higher Estimate                  Type  \
# 0                                 0.1  Predicted (weighted)
# 10638                             0.1  Predicted (weighted)
# 21276                             0.1            Unweighted
# 1                                 0.0  Predicted (weighted)
# 10639                             0.0  Predicted (weighted)
#
#                               Outcome Suppress Note
# 0                          All causes      NaN  NaN
# 10638  All causes, excluding COVID-19      NaN  NaN
# 21276                      All causes      NaN  NaN
# 1                          All causes      NaN  NaN
# 10639  All causes, excluding COVID-19      NaN  NaN

# %%
# Determine how many weeks NCHS believes data were incomplete at time of initial reporting

al_df2 = al_df.dropna(subset=["Note"])
al_df3 = al_df2.loc[al_df2["Type"] == "Unweighted"]
note_list = al_df3["Note"].unique()
print(f"Instances of Non-Null Note Values = {len(al_df3)}\n")
print(f"Number of Unique Note Values = {len(note_list)}\n")
print(note_list)

# "Data in recent weeks are incomplete. Only 60% of death records are submitted to NCHS within 10 days of 
#     the date of death, and completeness varies by jurisdiction. Data are not weighted and counts are likely
#     underreported."
# Out:
# Instances of Non-Null Note Values = 38
#
# Number of Unique Note Values = 1
#
# ['Data in recent weeks are incomplete. Only 60% of death records are submitted to NCHS within 10 days of the date of death, and completeness varies by jurisdiction. Data are not weighted and counts are likely underreported.']

# %%
al_wt_all_df = al_df.loc[(al_df["Type"] == "Predicted (weighted)") & (al_df["Outcome"] == "All causes")]
al_wt_all_df.tail()
# Out:
#     Week Ending Date    State  Observed Number  Upper Bound Threshold  \
# 192       2020-09-19  Alabama           1183.0                 1057.0
# 193       2020-09-26  Alabama           1157.0                 1050.0
# 194       2020-10-03  Alabama           1082.0                 1056.0
# 195       2020-10-10  Alabama           1136.0                 1056.0
# 196       2020-10-17  Alabama           1031.0                 1046.0
#
#      Exceeds Threshold  Average Expected Count  Excess Lower Estimate  \
# 192               True                   980.0                  126.0
# 193               True                   976.0                  107.0
# 194               True                   984.0                   26.0
# 195               True                   985.0                   80.0
# 196              False                   976.0                    0.0
#
#      Excess Higher Estimate  Year  Total Excess Lower Estimate in 2020  \
# 192                   203.0  2020                                 3743
# 193                   181.0  2020                                 3743
# 194                    98.0  2020                                 3743
# 195                   151.0  2020                                 3743
# 196                    55.0  2020                                 3743
#
#      Total Excess Higher Estimate in 2020  Percent Excess Lower Estimate  \
# 192                                  5884                            0.1
# 193                                  5884                            0.1
# 194                                  5884                            0.0
# 195                                  5884                            0.1
# 196                                  5884                            0.0
#
#      Percent Excess Higher Estimate                  Type     Outcome  \
# 192                             0.2  Predicted (weighted)  All causes
# 193                             0.2  Predicted (weighted)  All causes
# 194                             0.1  Predicted (weighted)  All causes
# 195                             0.2  Predicted (weighted)  All causes
# 196                             0.1  Predicted (weighted)  All causes
#
#     Suppress                                               Note
# 192      NaN  Data in recent weeks are incomplete. Only 60% ...
# 193      NaN  Data in recent weeks are incomplete. Only 60% ...
# 194      NaN  Data in recent weeks are incomplete. Only 60% ...
# 195      NaN  Data in recent weeks are incomplete. Only 60% ...
# 196      NaN  Data in recent weeks are incomplete. Only 60% ...

# %%
al_wt_xcov_df = al_df.loc[(al_df["Type"] == "Predicted (weighted)") & (al_df["Outcome"] == "All causes, excluding COVID-19")]
al_wt_xcov_df.tail()
# Out:
#       Week Ending Date    State  Observed Number  Upper Bound Threshold  \
# 10830       2020-09-19  Alabama           1045.0                 1057.0
# 10831       2020-09-26  Alabama           1054.0                 1050.0
# 10832       2020-10-03  Alabama            971.0                 1056.0
# 10833       2020-10-10  Alabama           1012.0                 1056.0
# 10834       2020-10-17  Alabama            935.0                 1046.0
#
#        Exceeds Threshold  Average Expected Count  Excess Lower Estimate  \
# 10830              False                   980.0                    0.0
# 10831               True                   976.0                    4.0
# 10832              False                   984.0                    0.0
# 10833              False                   985.0                    0.0
# 10834              False                   976.0                    0.0
#
#        Excess Higher Estimate  Year  Total Excess Lower Estimate in 2020  \
# 10830                    65.0  2020                                  499
# 10831                    78.0  2020                                  499
# 10832                     0.0  2020                                  499
# 10833                    27.0  2020                                  499
# 10834                     0.0  2020                                  499
#
#        Total Excess Higher Estimate in 2020  Percent Excess Lower Estimate  \
# 10830                                  2080                            0.0
# 10831                                  2080                            0.0
# 10832                                  2080                            0.0
# 10833                                  2080                            0.0
# 10834                                  2080                            0.0
#
#        Percent Excess Higher Estimate                  Type  \
# 10830                             0.1  Predicted (weighted)
# 10831                             0.1  Predicted (weighted)
# 10832                             0.0  Predicted (weighted)
# 10833                             0.0  Predicted (weighted)
# 10834                             0.0  Predicted (weighted)
#
#                               Outcome Suppress  \
# 10830  All causes, excluding COVID-19      NaN
# 10831  All causes, excluding COVID-19      NaN
# 10832  All causes, excluding COVID-19      NaN
# 10833  All causes, excluding COVID-19      NaN
# 10834  All causes, excluding COVID-19      NaN
#
#                                                     Note
# 10830  Data in recent weeks are incomplete. Only 60% ...
# 10831  Data in recent weeks are incomplete. Only 60% ...
# 10832  Data in recent weeks are incomplete. Only 60% ...
# 10833  Data in recent weeks are incomplete. Only 60% ...
# 10834  Data in recent weeks are incomplete. Only 60% ...

# %%
# Extract into a new DataFrame the following columns of Data:
#     State, Week Ending Date, Total Deaths, and Average Expected Deaths
#     Rename columns as appropriate
al_sum_df = al_wt_all_df[["State","Week Ending Date","Observed Number","Average Expected Count"]]
al_sum_df = al_sum_df.rename(columns={"Observed Number": "Total Deaths", "Average Expected Count": "Avg Expect Deaths"})
al_sum_df.head()
# Out:
#      State Week Ending Date  Total Deaths  Avg Expect Deaths
# 0  Alabama       2017-01-14        1130.0             1029.0
# 1  Alabama       2017-01-21        1048.0             1042.0
# 2  Alabama       2017-01-28        1026.0             1057.0
# 3  Alabama       2017-02-04        1036.0             1057.0
# 4  Alabama       2017-02-11        1058.0             1053.0

# %%
# Extract Total Deaths Excluding Covid-19 into a list
deaths_xcov = al_wt_xcov_df["Observed Number"].tolist()
deaths_xcov
# Out:
# [1130.0,
#  1048.0,
#  1026.0,
#  1036.0,
#  1058.0,
#  1060.0,
#  1099.0,
#  1081.0,
#  1011.0,
#  1067.0,
#  1068.0,
#  991.0,
#  1037.0,
#  1017.0,
#  966.0,
#  996.0,
#  907.0,
#  1064.0,
#  998.0,
#  988.0,
#  925.0,
#  984.0,
#  918.0,
#  961.0,
#  925.0,
#  954.0,
#  968.0,
#  964.0,
#  888.0,
#  949.0,
#  936.0,
#  933.0,
#  917.0,
#  953.0,
#  960.0,
#  968.0,
#  995.0,
#  1019.0,
#  948.0,
#  986.0,
#  966.0,
#  941.0,
#  994.0,
#  994.0,
#  982.0,
#  1004.0,
#  1067.0,
#  1074.0,
#  1120.0,
#  1098.0,
#  1080.0,
#  1248.0,
#  1301.0,
#  1275.0,
#  1286.0,
#  1147.0,
#  1181.0,
#  1096.0,
#  1099.0,
#  985.0,
#  1059.0,
#  1086.0,
#  993.0,
#  995.0,
#  1012.0,
#  1026.0,
#  1031.0,
#  971.0,
#  1039.0,
#  950.0,
#  1005.0,
#  977.0,
#  973.0,
#  1011.0,
#  940.0,
#  974.0,
#  927.0,
#  972.0,
#  994.0,
#  959.0,
#  930.0,
#  962.0,
#  969.0,
#  938.0,
#  943.0,
#  936.0,
#  944.0,
#  912.0,
#  998.0,
#  972.0,
#  945.0,
#  943.0,
#  971.0,
#  993.0,
#  927.0,
#  963.0,
#  1055.0,
#  1009.0,
#  1050.0,
#  1044.0,
#  1053.0,
#  1105.0,
#  1084.0,
#  1077.0,
#  1090.0,
#  1114.0,
#  1063.0,
#  1095.0,
#  1092.0,
#  1103.0,
#  1064.0,
#  1050.0,
#  1062.0,
#  1090.0,
#  1012.0,
#  1079.0,
#  1044.0,
#  1031.0,
#  954.0,
#  1042.0,
#  1031.0,
#  1009.0,
#  996.0,
#  974.0,
#  1027.0,
#  1029.0,
#  986.0,
#  989.0,
#  940.0,
#  1028.0,
#  1018.0,
#  962.0,
#  980.0,
#  984.0,
#  998.0,
#  977.0,
#  939.0,
#  975.0,
#  1009.0,
#  1000.0,
#  883.0,
#  987.0,
#  958.0,
#  907.0,
#  1009.0,
#  978.0,
#  937.0,
#  1041.0,
#  1070.0,
#  1043.0,
#  1038.0,
#  1072.0,
#  1081.0,
#  1103.0,
#  1035.0,
#  1080.0,
#  1124.0,
#  1039.0,
#  1053.0,
#  1024.0,
#  1117.0,
#  1093.0,
#  1096.0,
#  1161.0,
#  1053.0,
#  1088.0,
#  1054.0,
#  1048.0,
#  1104.0,
#  1051.0,
#  1050.0,
#  1053.0,
#  1065.0,
#  1058.0,
#  1057.0,
#  1076.0,
#  1006.0,
#  1084.0,
#  1059.0,
#  1002.0,
#  1048.0,
#  1082.0,
#  1124.0,
#  1101.0,
#  1085.0,
#  1099.0,
#  1107.0,
#  1067.0,
#  1081.0,
#  1028.0,
#  1054.0,
#  1100.0,
#  1045.0,
#  1054.0,
#  971.0,
#  1012.0,
#  935.0]

# %%
# Append Total Deaths Excluding Covid-19 into a new column
al_sum_df["Ttl Deaths x-Cov"] = al_wt_xcov_df["Observed Number"].tolist()
al_sum_df.head()
# Out:
#      State Week Ending Date  Total Deaths  Avg Expect Deaths  Ttl Deaths x-Cov
# 0  Alabama       2017-01-14        1130.0             1029.0            1130.0
# 1  Alabama       2017-01-21        1048.0             1042.0            1048.0
# 2  Alabama       2017-01-28        1026.0             1057.0            1026.0
# 3  Alabama       2017-02-04        1036.0             1057.0            1036.0
# 4  Alabama       2017-02-11        1058.0             1053.0            1058.0

# %%
# Calculate Covid-19 Deaths and Append Column
al_sum_df["Cov Deaths"] = al_sum_df["Total Deaths"] - al_sum_df["Ttl Deaths x-Cov"]
al_sum_df.head()
# Out:
#      State Week Ending Date  Total Deaths  Avg Expect Deaths  \
# 0  Alabama       2017-01-14        1130.0             1029.0
# 1  Alabama       2017-01-21        1048.0             1042.0
# 2  Alabama       2017-01-28        1026.0             1057.0
# 3  Alabama       2017-02-04        1036.0             1057.0
# 4  Alabama       2017-02-11        1058.0             1053.0
#
#    Ttl Deaths x-Cov  Cov Deaths
# 0            1130.0         0.0
# 1            1048.0         0.0
# 2            1026.0         0.0
# 3            1036.0         0.0
# 4            1058.0         0.0

# %%
# Calculate Excess Deaths and Append Column
al_sum_df["Excess Deaths"] = al_sum_df["Ttl Deaths x-Cov"] - al_sum_df["Avg Expect Deaths"]
al_sum_df.tail()
# Out:
#        State Week Ending Date  Total Deaths  Avg Expect Deaths  \
# 192  Alabama       2020-09-19        1183.0              980.0
# 193  Alabama       2020-09-26        1157.0              976.0
# 194  Alabama       2020-10-03        1082.0              984.0
# 195  Alabama       2020-10-10        1136.0              985.0
# 196  Alabama       2020-10-17        1031.0              976.0
#
#      Ttl Deaths x-Cov  Cov Deaths  Excess Deaths
# 192            1045.0       138.0           65.0
# 193            1054.0       103.0           78.0
# 194             971.0       111.0          -13.0
# 195            1012.0       124.0           27.0
# 196             935.0        96.0          -41.0

# %%
# Calculate total negative values for Excess Deaths for entire period
excess_neg_df = al_sum_df.loc[al_sum_df["Excess Deaths"] < 0]
excess_neg_df["Excess Deaths"].sum()
# Out:
# -4920.0

# %%
# Calculate total positive values for Excess Deaths for entire period
excess_pos_df = al_sum_df.loc[al_sum_df["Excess Deaths"] >= 0]
excess_pos_df["Excess Deaths"].sum()
# Out:
# 4032.0

# %%
# Remove negative values in Excess Deaths column
al_sum_df["Excess Deaths"] = np.where(al_sum_df["Excess Deaths"] < 0, 0, al_sum_df["Excess Deaths"])
al_sum_df.tail()
# Out:
#        State Week Ending Date  Total Deaths  Avg Expect Deaths  \
# 192  Alabama       2020-09-19        1183.0              980.0
# 193  Alabama       2020-09-26        1157.0              976.0
# 194  Alabama       2020-10-03        1082.0              984.0
# 195  Alabama       2020-10-10        1136.0              985.0
# 196  Alabama       2020-10-17        1031.0              976.0
#
#      Ttl Deaths x-Cov  Cov Deaths  Excess Deaths
# 192            1045.0       138.0           65.0
# 193            1054.0       103.0           78.0
# 194             971.0       111.0            0.0
# 195            1012.0       124.0           27.0
# 196             935.0        96.0            0.0

# %%
al_sum_df["Prob Ttl Cov Deaths"] = al_sum_df["Cov Deaths"] + al_sum_df["Excess Deaths"]
al_sum_df.tail()
# Out:
#        State Week Ending Date  Total Deaths  Avg Expect Deaths  \
# 192  Alabama       2020-09-19        1183.0              980.0
# 193  Alabama       2020-09-26        1157.0              976.0
# 194  Alabama       2020-10-03        1082.0              984.0
# 195  Alabama       2020-10-10        1136.0              985.0
# 196  Alabama       2020-10-17        1031.0              976.0
#
#      Ttl Deaths x-Cov  Cov Deaths  Excess Deaths  Prob Ttl Cov Deaths
# 192            1045.0       138.0           65.0                203.0
# 193            1054.0       103.0           78.0                181.0
# 194             971.0       111.0            0.0                111.0
# 195            1012.0       124.0           27.0                151.0
# 196             935.0        96.0            0.0                 96.0

# %%
al_sum_df["Prob Under Report %"] = (al_sum_df["Excess Deaths"] / al_sum_df["Prob Ttl Cov Deaths"]) * 100
al_sum_df.tail(33)
# Out:
#        State Week Ending Date  Total Deaths  Avg Expect Deaths  \
# 164  Alabama       2020-03-07        1053.0             1074.0
# 165  Alabama       2020-03-14        1088.0             1067.0
# 166  Alabama       2020-03-21        1057.0             1062.0
# 167  Alabama       2020-03-28        1071.0             1056.0
# 168  Alabama       2020-04-04        1153.0             1041.0
# 169  Alabama       2020-04-11        1132.0             1036.0
# 170  Alabama       2020-04-18        1139.0             1031.0
# 171  Alabama       2020-04-25        1136.0             1023.0
# 172  Alabama       2020-05-02        1146.0             1018.0
# 173  Alabama       2020-05-09        1174.0             1013.0
# 174  Alabama       2020-05-16        1152.0             1012.0
# 175  Alabama       2020-05-23        1156.0             1006.0
# 176  Alabama       2020-05-30        1110.0             1010.0
# 177  Alabama       2020-06-06        1172.0              995.0
# 178  Alabama       2020-06-13        1141.0              990.0
# 179  Alabama       2020-06-20        1090.0              985.0
# 180  Alabama       2020-06-27        1150.0              983.0
# 181  Alabama       2020-07-04        1204.0              980.0
# 182  Alabama       2020-07-11        1258.0              981.0
# 183  Alabama       2020-07-18        1292.0              979.0
# 184  Alabama       2020-07-25        1333.0              977.0
# 185  Alabama       2020-08-01        1363.0              971.0
# 186  Alabama       2020-08-08        1369.0              967.0
# 187  Alabama       2020-08-15        1295.0              964.0
# 188  Alabama       2020-08-22        1290.0              968.0
# 189  Alabama       2020-08-29        1213.0              966.0
# 190  Alabama       2020-09-05        1211.0              967.0
# 191  Alabama       2020-09-12        1237.0              975.0
# 192  Alabama       2020-09-19        1183.0              980.0
# 193  Alabama       2020-09-26        1157.0              976.0
# 194  Alabama       2020-10-03        1082.0              984.0
# 195  Alabama       2020-10-10        1136.0              985.0
# 196  Alabama       2020-10-17        1031.0              976.0
#
#      Ttl Deaths x-Cov  Cov Deaths  Excess Deaths  Prob Ttl Cov Deaths  \
# 164            1053.0         0.0            0.0                  0.0
# 165            1088.0         0.0           21.0                 21.0
# 166            1054.0         3.0            0.0                  3.0
# 167            1048.0        23.0            0.0                 23.0
# 168            1104.0        49.0           63.0                112.0
# 169            1051.0        81.0           15.0                 96.0
# 170            1050.0        89.0           19.0                108.0
# 171            1053.0        83.0           30.0                113.0
# 172            1065.0        81.0           47.0                128.0
# 173            1058.0       116.0           45.0                161.0
# 174            1057.0        95.0           45.0                140.0
# 175            1076.0        80.0           70.0                150.0
# 176            1006.0       104.0            0.0                104.0
# 177            1084.0        88.0           89.0                177.0
# 178            1059.0        82.0           69.0                151.0
# 179            1002.0        88.0           17.0                105.0
# 180            1048.0       102.0           65.0                167.0
# 181            1082.0       122.0          102.0                224.0
# 182            1124.0       134.0          143.0                277.0
# 183            1101.0       191.0          122.0                313.0
# 184            1085.0       248.0          108.0                356.0
# 185            1099.0       264.0          128.0                392.0
# 186            1107.0       262.0          140.0                402.0
# 187            1067.0       228.0          103.0                331.0
# 188            1081.0       209.0          113.0                322.0
# 189            1028.0       185.0           62.0                247.0
# 190            1054.0       157.0           87.0                244.0
# 191            1100.0       137.0          125.0                262.0
# 192            1045.0       138.0           65.0                203.0
# 193            1054.0       103.0           78.0                181.0
# 194             971.0       111.0            0.0                111.0
# 195            1012.0       124.0           27.0                151.0
# 196             935.0        96.0            0.0                 96.0
#
#      Prob Under Report %
# 164                  NaN
# 165           100.000000
# 166             0.000000
# 167             0.000000
# 168            56.250000
# 169            15.625000
# 170            17.592593
# 171            26.548673
# 172            36.718750
# 173            27.950311
# 174            32.142857
# 175            46.666667
# 176             0.000000
# 177            50.282486
# 178            45.695364
# 179            16.190476
# 180            38.922156
# 181            45.535714
# 182            51.624549
# 183            38.977636
# 184            30.337079
# 185            32.653061
# 186            34.825871
# 187            31.117825
# 188            35.093168
# 189            25.101215
# 190            35.655738
# 191            47.709924
# 192            32.019704
# 193            43.093923
# 194             0.000000
# 195            17.880795
# 196             0.000000

# %%
# Extract first state (Alabama) results to master DataFrame
covid_deaths_df = al_sum_df[["State","Week Ending Date","Cov Deaths","Prob Ttl Cov Deaths", "Prob Under Report %"]].tail(33)

# Replace NaN value (due to divide by zero) with zero value in a single column
covid_deaths_df["Prob Under Report %"] = covid_deaths_df["Prob Under Report %"].fillna(0)

covid_deaths_df = covid_deaths_df.reset_index(drop=True)

covid_deaths_df
# Out:
#       State Week Ending Date  Cov Deaths  Prob Ttl Cov Deaths  \
# 0   Alabama       2020-03-07         0.0                  0.0
# 1   Alabama       2020-03-14         0.0                 21.0
# 2   Alabama       2020-03-21         3.0                  3.0
# 3   Alabama       2020-03-28        23.0                 23.0
# 4   Alabama       2020-04-04        49.0                112.0
# 5   Alabama       2020-04-11        81.0                 96.0
# 6   Alabama       2020-04-18        89.0                108.0
# 7   Alabama       2020-04-25        83.0                113.0
# 8   Alabama       2020-05-02        81.0                128.0
# 9   Alabama       2020-05-09       116.0                161.0
# 10  Alabama       2020-05-16        95.0                140.0
# 11  Alabama       2020-05-23        80.0                150.0
# 12  Alabama       2020-05-30       104.0                104.0
# 13  Alabama       2020-06-06        88.0                177.0
# 14  Alabama       2020-06-13        82.0                151.0
# 15  Alabama       2020-06-20        88.0                105.0
# 16  Alabama       2020-06-27       102.0                167.0
# 17  Alabama       2020-07-04       122.0                224.0
# 18  Alabama       2020-07-11       134.0                277.0
# 19  Alabama       2020-07-18       191.0                313.0
# 20  Alabama       2020-07-25       248.0                356.0
# 21  Alabama       2020-08-01       264.0                392.0
# 22  Alabama       2020-08-08       262.0                402.0
# 23  Alabama       2020-08-15       228.0                331.0
# 24  Alabama       2020-08-22       209.0                322.0
# 25  Alabama       2020-08-29       185.0                247.0
# 26  Alabama       2020-09-05       157.0                244.0
# 27  Alabama       2020-09-12       137.0                262.0
# 28  Alabama       2020-09-19       138.0                203.0
# 29  Alabama       2020-09-26       103.0                181.0
# 30  Alabama       2020-10-03       111.0                111.0
# 31  Alabama       2020-10-10       124.0                151.0
# 32  Alabama       2020-10-17        96.0                 96.0
#
#     Prob Under Report %
# 0              0.000000
# 1            100.000000
# 2              0.000000
# 3              0.000000
# 4             56.250000
# 5             15.625000
# 6             17.592593
# 7             26.548673
# 8             36.718750
# 9             27.950311
# 10            32.142857
# 11            46.666667
# 12             0.000000
# 13            50.282486
# 14            45.695364
# 15            16.190476
# 16            38.922156
# 17            45.535714
# 18            51.624549
# 19            38.977636
# 20            30.337079
# 21            32.653061
# 22            34.825871
# 23            31.117825
# 24            35.093168
# 25            25.101215
# 26            35.655738
# 27            47.709924
# 28            32.019704
# 29            43.093923
# 30             0.000000
# 31            17.880795
# 32             0.000000

# %%
# USE FOR LOOP TO TRAVERSE LIST OF STATES AGAINST A BLOCK OF CODE THAT EXTRACTS AND PROCESSES
#    THE CDC EXCESS DEATHS DATA SET TO YIELD A PROCESSED WEEKLY DATA SET BEGINNING IN MARCH 2020
#    AND RUNS TO OCTOBER 2020 (33 WEEKS), FOR EACH OF THE 50 US STATES.  THE KEY DATA BEING ANALYZED 
#    ARE (1) AFFIRMATIVELY REPORTED CASES OF COVID-19 DEATHS, (2) AN INFERENCED PROBABLE TOTAL 
#    COVID-19 DEATHS SINCE EXCESS BUT UNEXPLAINED DEATHS ARE PROBABLLISTICALLY LIKELY TO BE 
#    COVID-19 DEATHS, AND (3) A PERCENTAGE FIGURE THAT REPRESENTS THE DEGREE OF UNDER-REPORTING
#    OF COVID-19 DEATHS.  THE EXCESS DEATHS FIGURE IS BASED ON THE TOTAL OBSERVED DEATHS LESS
#    THE EXPECTED NUMBER OF DEATHS LESS THE NUMBER OF REPORTED COVID CASES.

# %%
# Create an empty dataframe with column headers

master_df = pd.DataFrame(columns = ["State", "Week Ending Date","Cov Deaths","Prob Ttl Cov Deaths", "Prob Under Report %"])
master_df
# Out:
# Empty DataFrame
# Columns: [State, Week Ending Date, Cov Deaths, Prob Ttl Cov Deaths, Prob Under Report %]
# Index: []

# %%
# Create a for loop
for state in states_list:
    
    df1 = df.loc[df['State'] == state]
    
    wt_all_df = df1.loc[(df1["Type"] == "Predicted (weighted)") & (df1["Outcome"] == "All causes")]
    wt_xcov_df = df1.loc[(df1["Type"] == "Predicted (weighted)") & (df1["Outcome"] == "All causes, excluding COVID-19")]
    
    sum_df = wt_all_df[["State","Week Ending Date","Observed Number","Average Expected Count"]]
    sum_df = sum_df.rename(columns={"Observed Number": "Total Deaths", "Average Expected Count": "Avg Expect Deaths"})
    
    sum_df["Ttl Deaths x-Cov"] = wt_xcov_df["Observed Number"].tolist()
    
    sum_df["Cov Deaths"] = sum_df["Total Deaths"] - sum_df["Ttl Deaths x-Cov"]
    
    sum_df["Excess Deaths"] = sum_df["Ttl Deaths x-Cov"] - sum_df["Avg Expect Deaths"]
    
    sum_df["Excess Deaths"] = np.where(sum_df["Excess Deaths"] < 0, 0, sum_df["Excess Deaths"])
    
    sum_df["Prob Ttl Cov Deaths"] = sum_df["Cov Deaths"] + sum_df["Excess Deaths"]
    
    sum_df["Prob Under Report %"] = (sum_df["Excess Deaths"] / sum_df["Prob Ttl Cov Deaths"]) * 100
    
    state_cov_deaths_df = sum_df[["State","Week Ending Date","Cov Deaths","Prob Ttl Cov Deaths", "Prob Under Report %"]].tail(33)
    
    state_cov_deaths_df["Prob Under Report %"] = state_cov_deaths_df["Prob Under Report %"].fillna(0)
    
    state_cov_deaths_df = state_cov_deaths_df.reset_index(drop=True)
    
    # Combine the data into a single dataset
    
    # x = master_df.append(state_cov_deaths_df, ignore_index = True)                             )
    
    master_df = master_df.append(state_cov_deaths_df)

master_df.head()
# Out:
#      State Week Ending Date  Cov Deaths  Prob Ttl Cov Deaths  \
# 0  Alabama       2020-03-07         0.0                  0.0
# 1  Alabama       2020-03-14         0.0                 21.0
# 2  Alabama       2020-03-21         3.0                  3.0
# 3  Alabama       2020-03-28        23.0                 23.0
# 4  Alabama       2020-04-04        49.0                112.0
#
#    Prob Under Report %
# 0                 0.00
# 1               100.00
# 2                 0.00
# 3                 0.00
# 4                56.25

# %%
d = {'Cov Deaths':'Pos-ID Covid Deaths', \
     'Prob Ttl Cov Deaths':'Prob Ttl Cov Deaths',\
     'Prob Under Report %':'Est. Under-Report %'}
master_group = master_df.groupby("State").agg({'Cov Deaths':'sum', \
                                               'Prob Ttl Cov Deaths':'sum',\
                                               'Prob Under Report %':'mean'}).rename(columns=d)

df.round(1)

master_group
# Out:
#                 Pos-ID Covid Deaths  Prob Ttl Cov Deaths  Est. Under-Report %
# State
# Alabama                      7746.0              11742.0            30.673077
# Alaska                        124.0                414.0            46.850366
# Arizona                     10544.0              18730.0            44.762199
# Arkansas                     3338.0               6012.0            35.233997
# California                  33598.0              53108.0            35.362307
# Colorado                     4220.0               7584.0            47.898324
# Connecticut                  9028.0              11076.0            29.776178
# Delaware                     1220.0               2514.0            53.757716
# Florida                     32340.0              46906.0            31.413797
# Georgia                     14016.0              21240.0            34.534819
# Hawaii                        486.0                770.0            25.014947
# Idaho                        1152.0               2094.0            38.185147
# Illinois                    16990.0              26834.0            44.197585
# Indiana                      8428.0              13014.0            39.315019
# Iowa                         3340.0               4666.0            25.104242
# Kansas                       1958.0               3334.0            34.276815
# Kentucky                     3182.0               6606.0            44.941178
# Louisiana                   10752.0              15646.0            34.525878
# Maine                         336.0                940.0            43.941881
# Maryland                     8914.0              13294.0            39.886162
# Massachusetts               16444.0              18358.0            11.824725
# Michigan                    13262.0              25220.0            55.648029
# Minnesota                    4612.0               5678.0            20.749976
# Mississippi                  6350.0               9530.0            32.884706
# Missouri                     6024.0               9856.0            36.350084
# Montana                       532.0               1332.0            43.107905
# Nebraska                     1336.0               2296.0            30.759904
# Nevada                       3302.0               5068.0            24.497587
# New Hampshire                 906.0               1552.0            36.219123
# New Jersey                  29112.0              37502.0            16.690244
# New Mexico                   1764.0               3514.0            45.839492
# New York                    23696.0              30652.0            28.059274
# North Carolina               5358.0               8444.0            27.830295
# North Dakota                  876.0               1362.0            28.029932
# Ohio                        10092.0              16884.0            36.440829
# Oklahoma                     2966.0               4684.0            29.211033
# Oregon                       1236.0               3516.0            52.514491
# Pennsylvania                17786.0              24038.0            35.264410
# Rhode Island                 2352.0               2778.0            20.920464
# South Carolina               7344.0              12928.0            43.923395
# South Dakota                  810.0               1240.0            23.932486
# Tennessee                    6052.0              11542.0            40.937775
# Texas                       36010.0              53196.0            37.357936
# Utah                         1178.0               2568.0            45.752435
# Vermont                       128.0               1182.0            77.629795
# Virginia                     7026.0              11324.0            40.401273
# Washington                   4134.0               6192.0            25.450394
# West Virginia                 900.0               2132.0            48.455753
# Wisconsin                    3398.0               5678.0            40.712818
# Wyoming                       122.0                686.0            54.749049

# %%
master_group['Under-Report Check'] = (1 - (master_group['Pos-ID Covid Deaths'] / master_group['Prob Ttl Cov Deaths'])) * 100
master_group
# Out:
#                 Pos-ID Covid Deaths  Prob Ttl Cov Deaths  Est. Under-Report %  \
# State
# Alabama                      7746.0              11742.0            30.673077
# Alaska                        124.0                414.0            46.850366
# Arizona                     10544.0              18730.0            44.762199
# Arkansas                     3338.0               6012.0            35.233997
# California                  33598.0              53108.0            35.362307
# Colorado                     4220.0               7584.0            47.898324
# Connecticut                  9028.0              11076.0            29.776178
# Delaware                     1220.0               2514.0            53.757716
# Florida                     32340.0              46906.0            31.413797
# Georgia                     14016.0              21240.0            34.534819
# Hawaii                        486.0                770.0            25.014947
# Idaho                        1152.0               2094.0            38.185147
# Illinois                    16990.0              26834.0            44.197585
# Indiana                      8428.0              13014.0            39.315019
# Iowa                         3340.0               4666.0            25.104242
# Kansas                       1958.0               3334.0            34.276815
# Kentucky                     3182.0               6606.0            44.941178
# Louisiana                   10752.0              15646.0            34.525878
# Maine                         336.0                940.0            43.941881
# Maryland                     8914.0              13294.0            39.886162
# Massachusetts               16444.0              18358.0            11.824725
# Michigan                    13262.0              25220.0            55.648029
# Minnesota                    4612.0               5678.0            20.749976
# Mississippi                  6350.0               9530.0            32.884706
# Missouri                     6024.0               9856.0            36.350084
# Montana                       532.0               1332.0            43.107905
# Nebraska                     1336.0               2296.0            30.759904
# Nevada                       3302.0               5068.0            24.497587
# New Hampshire                 906.0               1552.0            36.219123
# New Jersey                  29112.0              37502.0            16.690244
# New Mexico                   1764.0               3514.0            45.839492
# New York                    23696.0              30652.0            28.059274
# North Carolina               5358.0               8444.0            27.830295
# North Dakota                  876.0               1362.0            28.029932
# Ohio                        10092.0              16884.0            36.440829
# Oklahoma                     2966.0               4684.0            29.211033
# Oregon                       1236.0               3516.0            52.514491
# Pennsylvania                17786.0              24038.0            35.264410
# Rhode Island                 2352.0               2778.0            20.920464
# South Carolina               7344.0              12928.0            43.923395
# South Dakota                  810.0               1240.0            23.932486
# Tennessee                    6052.0              11542.0            40.937775
# Texas                       36010.0              53196.0            37.357936
# Utah                         1178.0               2568.0            45.752435
# Vermont                       128.0               1182.0            77.629795
# Virginia                     7026.0              11324.0            40.401273
# Washington                   4134.0               6192.0            25.450394
# West Virginia                 900.0               2132.0            48.455753
# Wisconsin                    3398.0               5678.0            40.712818
# Wyoming                       122.0                686.0            54.749049
#
#                 Under-Report Check
# State
# Alabama                  34.031681
# Alaska                   70.048309
# Arizona                  43.705286
# Arkansas                 44.477711
# California               36.736462
# Colorado                 44.356540
# Connecticut              18.490430
# Delaware                 51.471758
# Florida                  31.053597
# Georgia                  34.011299
# Hawaii                   36.883117
# Idaho                    44.985673
# Illinois                 36.684803
# Indiana                  35.238973
# Iowa                     28.418345
# Kansas                   41.271746
# Kentucky                 51.831668
# Louisiana                31.279560
# Maine                    64.255319
# Maryland                 32.947194
# Massachusetts            10.425972
# Michigan                 47.414750
# Minnesota                18.774216
# Mississippi              33.368311
# Missouri                 38.879870
# Montana                  60.060060
# Nebraska                 41.811847
# Nevada                   34.846093
# New Hampshire            41.623711
# New Jersey               22.372140
# New Mexico               49.800797
# New York                 22.693462
# North Carolina           36.546660
# North Dakota             35.682819
# Ohio                     40.227434
# Oklahoma                 36.678053
# Oregon                   64.846416
# Pennsylvania             26.008819
# Rhode Island             15.334773
# South Carolina           43.193069
# South Dakota             34.677419
# Tennessee                47.565413
# Texas                    32.306940
# Utah                     54.127726
# Vermont                  89.170897
# Virginia                 37.954786
# Washington               33.236434
# West Virginia            57.786116
# Wisconsin                40.154984
# Wyoming                  82.215743
