# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Path of csv file, originally converted using tabula
covid_nurse_home_path = "Resources/COVID-19_Nursing_Home_Dataset.csv"

# Read the csv file
covid_nurse_home_df = pd.read_csv(covid_nurse_home_path, low_memory=False)

# %%
# Display the data table for preview
print()
print(f"Nursing Home Covid-19 Dataset")
covid_nurse_home_df.head()
# Out:
# Nursing Home Covid-19 Dataset
#   Week Ending Federal Provider Number                      Provider Name  \
# 0   5/24/2020                   75300          APPLE REHAB SHELTON LAKES
# 1   5/24/2020                  105743                      FLEET LANDING
# 2   5/31/2020                  106105  SKYTOP VIEW REHABILITATION CENTER
# 3   5/24/2020                  106119  ADVENTHEALTH CARE CENTER WATERMAN
# 4   5/31/2020                  115606              CANTON NURSING CENTER
#
#                Provider Address   Provider City Provider State  \
# 0                   5 LAKE ROAD         SHELTON             CT
# 1        ONE FLEET LANDING BLVD  ATLANTIC BEACH             FL
# 2  2145 NORTH DON WICKHAM DRIVE        CLERMONT             FL
# 3             4501 WATERMAN WAY         TAVARES             FL
# 4             321 HOSPITAL ROAD          CANTON             GA
#
#    Provider Zip Code Submitted Data Passed Quality Assurance Check  \
# ...

# %%
covid_nurse_home_df.describe()
# Out:
#        Provider Zip Code  Residents Weekly Admissions COVID-19  \
# count      337872.000000                         331822.000000
# mean        50303.069257                              0.331256
# std         26853.324398                              1.961117
# min           660.000000                              0.000000
# 25%         29801.000000                              0.000000
# 50%         48823.000000                              0.000000
# 75%         72801.000000                              0.000000
# max         99929.000000                            212.000000
#
#        Residents Total Admissions COVID-19  \
# count                        331822.000000
# mean                              4.814925
# std                              14.123330
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               3.000000
# max                             390.000000
#
# ...

# %%
covid_nurse_home_by_drug_group = covid_nurse_home_df.groupby(["Provider State"]).sum()
covid_nurse_home_by_drug_group.head()
# Out:
#                 Provider Zip Code  Residents Weekly Admissions COVID-19  \
# Provider State
# AK                       43761645                                  20.0
# AL                      179780382                                1650.0
# AR                      356137276                                 610.0
# AZ                      272690088                                2508.0
# CA                     2427879666                               13047.0
#
#                 Residents Total Admissions COVID-19  \
# Provider State
# AK                                            181.0
# AL                                          20092.0
# AR                                           5900.0
# AZ                                          35227.0
# CA                                         178682.0
#
#                 Residents Weekly Confirmed COVID-19  \
# Provider State
# AK                                             30.0
# AL                                           7444.0
# ...
